# %%
import pandas as pd

# %%
df_images = pd.read_csv('/home/psa_images/SemiF-AnnotationPipeline/metrics/images_by_species_and_season.csv')

# %%
df_images.columns
# Out:
# Index(['Unnamed: 0', 'general_season', 'common_name', 'image_id'], dtype='object')

# %%
df_cutouts = pd.read_csv("/home/psa_images/SemiF-AnnotationPipeline/metrics/cutouts_by_species_and_season.csv")

# %%
df_cutouts.columns
# Out:
# Index(['Unnamed: 0', 'general_season', 'common_name', 'cutout_id'], dtype='object')

# %%
df_cc_images = df_images[df_images['general_season'] == 'cover crops']
df_cc_images = df_cc_images['image_id'].sum()
print(f'df_cc_images: {df_cc_images}')
# Out:
# df_cc_images: 25624

# %%
df_cash_images = df_images[df_images['general_season'] == 'cash crops']
df_cash_images = df_cash_images['image_id'].sum()
print(f'df_cash_images: {df_cash_images}')
# Out:
# df_cash_images: 18273

# %%
df_weeds_images = df_images[df_images['general_season'] == 'weeds']
df_weeds_images = df_weeds_images['image_id'].sum()
print(f'df_weeds_images: {df_weeds_images}')
# Out:
# df_weeds_images: 29749

# %%
df_cc_cutouts = df_cutouts[df_cutouts['general_season'] == 'cover crops']
df_cc_cutouts = df_cc_cutouts['cutout_id'].sum()
print(f'df_cc_cutouts: {df_cc_cutouts}')
# Out:
# df_cc_cutouts: 411906

# %%
df_cash_cutouts = df_cutouts[df_cutouts['general_season'] == 'cash crops']
# df_cc_cutouts_count = df_cc_cutouts['common_name'].unique()
# print(f'df_cc_cutouts_count: {df_cc_cutouts_count}')
df_cash_cutouts = df_cash_cutouts['cutout_id'].sum()
print(f'df_cash_cutouts: {df_cash_cutouts}')

df_cash_cutouts.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 3
#       1 df_cash_cutouts = df_cutouts[df_cutouts['general_season'] == 'cash crops']
#       2 # df_cc_cutouts_count = df_cc_cutouts['common_name'].unique()
# ----> 3 print(f'df_cc_cutouts_count: {df_cc_cutouts_count}')
#       4 df_cash_cutouts = df_cash_cutouts['cutout_id'].sum()
#       5 print(f'df_cash_cutouts: {df_cash_cutouts}')
#
# NameError: name 'df_cc_cutouts_count' is not defined

# %%
df_weeds_cutouts = df_cutouts[df_cutouts['general_season'] == 'weeds']
df_weeds_cutouts = df_weeds_cutouts['cutout_id'].sum()
print(f'df_weeds_cutouts: {df_weeds_cutouts}')
# Out:
# df_weeds_cutouts: 391436
